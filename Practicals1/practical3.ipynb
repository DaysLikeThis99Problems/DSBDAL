# %%
import pandas as pd
import numpy as np

df=pd.read_csv(r"C:\Users\sumit\OneDrive\Desktop\Student_performance.csv")
df
# Out:
#      gender race_ethnicity parental_level_of_education  lunch  \
# 0         0        group B           bachelor's degree      1
# 1         0        group C                some college      1
# 2         0        group B             master's degree      1
# 3         1        group A          associate's degree      0
# 4         1        group C                some college      1
# ..      ...            ...                         ...    ...
# 995       0        group E             master's degree      1
# 996       1        group C                 high school      0
# 997       0        group C                 high school      0
# 998       0        group D                some college      1
# 999       0        group D                some college      0
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# 0                          0          72             72             74
# 1                          1          69             90             88
# 2                          0          90             95             93
# 3                          0          47             57             44
# 4                          0          76             78             75
# ..                       ...         ...            ...            ...
# 995                        1          88             99             95
# 996                        0          62             55             55
# 997                        1          59             71             65
# 998                        1          68             78             77
# 999                        0          77             86             86
#
#      total_score  average_score
# 0            218      72.666667
# 1            247      82.333333
# 2            278      92.666667
# 3            148      49.333333
# 4            229      76.333333
# ..           ...            ...
# 995          282      94.000000
# 996          172      57.333333
# 997          195      65.000000
# 998          223      74.333333
# 999          249      83.000000
#
# [1000 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# gender                         0
# race_ethnicity                 0
# parental_level_of_education    0
# lunch                          0
# test_preparation_course        0
# math_score                     0
# reading_score                  0
# writing_score                  0
# total_score                    0
# average_score                  0
# dtype: int64

# %%
df.dtypes
# Out:
# gender                           int64
# race_ethnicity                  object
# parental_level_of_education     object
# lunch                            int64
# test_preparation_course          int64
# math_score                       int64
# reading_score                    int64
# writing_score                    int64
# total_score                      int64
# average_score                  float64
# dtype: object

# %%
q1=df.math_score.quantile(0.25)
q3=df.math_score.quantile(0.75)
q1,q3
# Out:
# (57.0, 77.0)

# %%
IQR=q3-q1
IQR
# Out:
# 20.0

# %%
lower_limit=q1-1.5*IQR
upper_limit=q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (27.0, 107.0)

# %%
df[(df.math_score<lower_limit)|(df.math_score>upper_limit)]
# Out:
#      gender race_ethnicity parental_level_of_education  lunch  \
# 17        0        group B            some high school      0
# 59        0        group C            some high school      0
# 145       0        group C                some college      0
# 338       0        group B            some high school      0
# 466       0        group D          associate's degree      0
# 787       0        group B                some college      1
# 842       0        group B                 high school      0
# 980       0        group B                 high school      0
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# 17                         0          18             32             28
# 59                         0           0             17             10
# 145                        0          22             39             33
# 338                        0          24             38             27
# 466                        0          26             31             38
# 787                        0          19             38             32
# 842                        1          23             44             36
# 980                        0           8             24             23
#
#      total_score  average_score
# 17            78      26.000000
# 59            27       9.000000
# 145           94      31.333333
# 338           89      29.666667
# 466           95      31.666667
# 787           89      29.666667
# 842          103      34.333333
# 980           55      18.333333

# %%
df[(df.math_score>lower_limit)&(df.math_score<upper_limit)]
# Out:
#      gender race_ethnicity parental_level_of_education  lunch  \
# 0         0        group B           bachelor's degree      1
# 1         0        group C                some college      1
# 2         0        group B             master's degree      1
# 3         1        group A          associate's degree      0
# 4         1        group C                some college      1
# ..      ...            ...                         ...    ...
# 995       0        group E             master's degree      1
# 996       1        group C                 high school      0
# 997       0        group C                 high school      0
# 998       0        group D                some college      1
# 999       0        group D                some college      0
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# 0                          0          72             72             74
# 1                          1          69             90             88
# 2                          0          90             95             93
# 3                          0          47             57             44
# 4                          0          76             78             75
# ..                       ...         ...            ...            ...
# 995                        1          88             99             95
# 996                        0          62             55             55
# 997                        1          59             71             65
# 998                        1          68             78             77
# 999                        0          77             86             86
#
#      total_score  average_score
# 0            218      72.666667
# 1            247      82.333333
# 2            278      92.666667
# 3            148      49.333333
# 4            229      76.333333
# ..           ...            ...
# 995          282      94.000000
# 996          172      57.333333
# 997          195      65.000000
# 998          223      74.333333
# 999          249      83.000000
#
# [990 rows x 10 columns]

# %%
df.describe()
# Out:
#             gender        lunch  test_preparation_course  math_score  \
# count  1000.000000  1000.000000              1000.000000  1000.00000
# mean      0.482000     0.645000                 0.358000    66.08900
# std       0.499926     0.478753                 0.479652    15.16308
# min       0.000000     0.000000                 0.000000     0.00000
# 25%       0.000000     0.000000                 0.000000    57.00000
# 50%       0.000000     1.000000                 0.000000    66.00000
# 75%       1.000000     1.000000                 1.000000    77.00000
# max       1.000000     1.000000                 1.000000   100.00000
#
#        reading_score  writing_score  total_score  average_score
# count    1000.000000    1000.000000  1000.000000    1000.000000
# mean       69.169000      68.054000   203.312000      67.770667
# std        14.600192      15.195657    42.771978      14.257326
# min        17.000000      10.000000    27.000000       9.000000
# 25%        59.000000      57.750000   175.000000      58.333333
# 50%        70.000000      69.000000   205.000000      68.333333
# 75%        79.000000      79.000000   233.000000      77.666667
# max       100.000000     100.000000   300.000000     100.000000

# %%
df['zscore']=(df.math_score-df.math_score.mean())/df.math_score.std()
df
# Out:
#      gender race_ethnicity parental_level_of_education  lunch  \
# 0         0        group B           bachelor's degree      1
# 1         0        group C                some college      1
# 2         0        group B             master's degree      1
# 3         1        group A          associate's degree      0
# 4         1        group C                some college      1
# ..      ...            ...                         ...    ...
# 995       0        group E             master's degree      1
# 996       1        group C                 high school      0
# 997       0        group C                 high school      0
# 998       0        group D                some college      1
# 999       0        group D                some college      0
#
#      test_preparation_course  math_score  reading_score  writing_score  \
# 0                          0          72             72             74
# 1                          1          69             90             88
# 2                          0          90             95             93
# 3                          0          47             57             44
# 4                          0          76             78             75
# ..                       ...         ...            ...            ...
# 995                        1          88             99             95
# 996                        0          62             55             55
# 997                        1          59             71             65
# 998                        1          68             78             77
# 999                        0          77             86             86
#
#      total_score  average_score    zscore
# 0            218      72.666667  0.389828
# 1            247      82.333333  0.191979
# 2            278      92.666667  1.576922
# 3            148      49.333333 -1.258913
# 4            229      76.333333  0.653627
# ..           ...            ...       ...
# 995          282      94.000000  1.445023
# 996          172      57.333333 -0.269668
# 997          195      65.000000 -0.467517
# 998          223      74.333333  0.126030
# 999          249      83.000000  0.719577
#
# [1000 rows x 11 columns]

# %%
import seaborn as sns
sns.boxplot(df["math_score"])
# Out:
# <Axes: ylabel='math_score'>
